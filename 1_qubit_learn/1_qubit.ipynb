# %%
from qiskit import __version__
import numpy as np
from qiskit.visualization import array_to_latex

# verison check
print(__version__)

# ket0 and ket1
# [[1],
#  [0]]
ket0 = np.array([[1], [0]])
# [[0],
#  [1]]
ket1 = np.array([[0], [1]])
#[[0.5]
# [0.5]]
superposition = (ket0 / 2 + ket1 / 2)
print(superposition)

M1 = np.array([[1, 1], [0, 0]])
M2 = np.array([[1, 0], [0, 1]])
M = M1 / 2 + M2 / 2
print(M1)
print(M2)
print(M)

print("matrix multiplication")
print(np.matmul(M1, ket1))
display(array_to_latex(np.matmul(M1, ket1)))
print(np.matmul(M1, M2))
display(array_to_latex(np.matmul(M1, M2)))
print(np.matmul(M,M))
display(array_to_latex(np.matmul(M,M)))
# Out:
# 2.3.1
# [[0.5]
#  [0.5]]
# [[1 1]
#  [0 0]]
# [[1 0]
#  [0 1]]
# [[1.  0.5]
#  [0.  0.5]]
# matrix multiplication
# [[1]
#  [0]]
# $$
#
# \begin{bmatrix}
# 1  \\
#  0  \\
#  \end{bmatrix}
# $$
# [[1 1]
#  [0 0]]
# $$
#
# \begin{bmatrix}
# 1 & 1  \\
#  0 & 0  \\
#  \end{bmatrix}
# $$
# [[1.   0.75]
#  [0.   0.25]]
# $$
#
# \begin{bmatrix}
# 1 & \frac{3}{4}  \\
#  0 & \frac{1}{4}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.quantum_info import Statevector
from numpy import sqrt

# %%
u = Statevector([1 / sqrt(2), 1 / sqrt(2)])
v = Statevector([(1 + 2.0j) / 3, -2 / 3])
w = Statevector([1 / 3, 2 / 3])

# %%
display(u.draw("text"))
display(u.draw("latex"))
print(u.draw("latex_source"))
# Out:
# [0.70710678+0.j,0.70710678+0.j]
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$$
# \frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle

# %%
display(u.is_valid())
display(w.is_valid())
# Out:
# True
# False

# %%
v = Statevector([(1 + 2.0j) / 3, -2 / 3])
display(v.draw("latex"))
# Out:
# $$(\frac{1}{3} + \frac{2 i}{3}) |0\rangle- \frac{2}{3} |1\rangle$$

# %%
outcome, state = v.measure()
print(f"Measured: {outcome}\nPost-measurement state:")
display(state.draw("latex"))
# Out:
# Measured: 1
# Post-measurement state:
# $$- |1\rangle$$

# %%
from qiskit.quantum_info import Statevector
from numpy import sqrt
from qiskit.visualization import plot_histogram
v = Statevector([(1 + 2.0j) / 3, -2 / 3])
statistics = v.sample_counts(1000)
plot_histogram(statistics)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from qiskit.quantum_info import Operator

Y = Operator([[0, -1.0j], [1.0j, 0]])
H = Operator([[1 / sqrt(2), 1 / sqrt(2)], [1 / sqrt(2), -1 / sqrt(2)]])
S = Operator([[1, 0], [0, 1.0j]])
T = Operator([[1, 0], [0, (1 + 1.0j) / sqrt(2)]])

display(T.draw("latex"))
# Out:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  0 & \frac{\sqrt{2}}{2} + \frac{\sqrt{2} i}{2}  \\
#  \end{bmatrix}
# $$

# %%
v = Statevector([1, 0])

v = v.evolve(H)
v = v.evolve(T)
v = v.evolve(H)
v = v.evolve(S)
v = v.evolve(Y)

display(v.draw("latex"))
# Out:
# $$(0.1464466094 - 0.3535533906 i) |0\rangle+(-0.3535533906 + 0.8535533906 i) |1\rangle$$

# %%
from qiskit import QuantumCircuit

circuit = QuantumCircuit(1)

circuit.h(0)
circuit.t(0)
circuit.h(0)
circuit.s(0)
circuit.y(0)

display(circuit.draw(output="mpl"))
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[7], line 11
#       8 circuit.s(0)
#       9 circuit.y(0)
# ---> 11 display(circuit.draw(output="mpl"))
#
# File ~/Documents/FPGA_PYNQ_Z2/.venv/lib/python3.14/site-packages/qiskit/circuit/quantumcircuit.py:4042, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows)
#    4039 # pylint: disable=cyclic-import
#    4040 from qiskit.visualization import circuit_drawer
# -> 4042 return circuit_drawer(
#    4043     self,
#    4044     scale=scale,
#    4045     filename=filename,
#    4046     style=style,
#    4047     output=output,
#    4048     interactive=interactive,
#    4049     plot_barriers=plot_barriers,
#    4050     reverse_bits=reverse_bits,
#    4051     justify=justify,
#    4052     vertical_compression=vertical_compression,
#    4053     idle_wires=idle_wires,
#    4054     with_layout=with_layout,
#    4055     fold=fold,
#    4056     ax=ax,
#    4057     initial_state=initial_state,
#    4058     cregbundle=cregbundle,
#    4059     wire_order=wire_order,
#    4060     expr_len=expr_len,
#    4061     measure_arrows=measure_arrows,
#    4062 )
#
# File ~/Documents/FPGA_PYNQ_Z2/.venv/lib/python3.14/site-packages/qiskit/visualization/circuit/circuit_visualization.py:360, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows)
#     345     return _generate_latex_source(
#     346         circuit,
#     347         filename=filename,
#    (...)    357         wire_order=complete_wire_order,
#     358     )
#     359 elif output == "mpl":
# --> 360     image = _matplotlib_circuit_drawer(
#     361         circuit,
#     362         scale=scale,
#     363         filename=filename,
#     364         style=style,
#     365         plot_barriers=plot_barriers,
#     366         reverse_bits=reverse_bits,
#     367         justify=justify,
#     368         idle_wires=idle_wires,
#     369         with_layout=with_layout,
#     370         fold=fold,
#     371         ax=ax,
#     372         initial_state=initial_state,
#     373         cregbundle=cregbundle,
#     374         wire_order=complete_wire_order,
#     375         expr_len=expr_len,
#     376         measure_arrows=measure_arrows,
#     377     )
#     378 else:
#     379     raise VisualizationError(
#     380         f"Invalid output type {output} selected. The only valid choices "
#     381         "are text, latex, latex_source, and mpl"
#     382     )
#
# File ~/Documents/FPGA_PYNQ_Z2/.venv/lib/python3.14/site-packages/qiskit/visualization/circuit/circuit_visualization.py:752, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows)
#     749 if fold is None:
#     750     fold = 25
# --> 752 qcd = _matplotlib.MatplotlibDrawer(
#     753     qubits,
#     754     clbits,
#     755     nodes,
#     756     circuit,
#     757     scale=scale,
#     758     style=style,
#     759     reverse_bits=reverse_bits,
#     760     plot_barriers=plot_barriers,
#     761     fold=fold,
#     762     ax=ax,
#     763     initial_state=initial_state,
#     764     cregbundle=cregbundle,
#     765     with_layout=with_layout,
#     766     expr_len=expr_len,
#     767     measure_arrows=measure_arrows,
#     768 )
#     769 return qcd.draw(filename)
#
# File ~/Documents/FPGA_PYNQ_Z2/.venv/lib/python3.14/site-packages/qiskit/utils/classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File ~/Documents/FPGA_PYNQ_Z2/.venv/lib/python3.14/site-packages/qiskit/utils/lazy_tester.py:41, in _RequireNow.__call__(self, *_args, **_kwargs)
#      40 def __call__(self, *_args, **_kwargs):
# ---> 41     self._tester.require_now(self._feature)
#
# File ~/Documents/FPGA_PYNQ_Z2/.venv/lib/python3.14/site-packages/qiskit/utils/lazy_tester.py:221, in LazyDependencyManager.require_now(self, feature)
#     219 if self:
#     220     return
# --> 221 raise MissingOptionalLibraryError(
#     222     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     223 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."
